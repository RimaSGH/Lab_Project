# %%
# !pip install forgi
# Out:
# Requirement already satisfied: forgi in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (2.1.2)
# Requirement already satisfied: pandas>=0.20 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (1.4.4)
# Requirement already satisfied: future in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (0.18.2)
# Requirement already satisfied: logging-exceptions>=0.1.8 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (0.1.8)
# Requirement already satisfied: numpy>=1.10.0 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (1.21.5)
# Requirement already satisfied: cython in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (0.29.32)
# Requirement already satisfied: biopython in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (1.81)
# Requirement already satisfied: scipy>=0.19.1 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (1.9.1)
# Requirement already satisfied: appdirs>=1.4 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (1.4.4)
# Requirement already satisfied: networkx>=2.0 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from forgi) (2.8.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.20->forgi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.20->forgi) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/Study/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.20->forgi) (1.16.0)

# %%
import forgi 
import forgi.graph.bulge_graph as fgb
import os
import shutil 
import pickle

# %%
def main(DBN_folder_path,dest_path,min_length):
  '''
  :DBN_folder_path: the path of the parent file of all DBN target files
                    target DBN files include free energy value
  :dest_path: the path of the parent file of the file that will include all new DBN files
                    new DBN files doesn't include free enrgy value, know as FASTA accoridng to the forgi documentation 
  '''

  #dest_path is the path of the parent folder of the new folder 
  new_DBN_folder_path=copyFolder(DBN_folder_path,dest_path,'_DBNfiles')


  #create folder that will contain all pickled files
  new_folder_name= os.path.basename(DBN_folder_path)+'_pickled'
  data_dir=os.path.join(dest_path,new_folder_name)
  os.mkdir(data_dir)

  ##iterate over new DBN files in order to modify them to *regular* DBN files 
  abs_paths_DBN_files= absoluteFilePaths(new_DBN_folder_path)

  i=0
  for DBN_file_path in abs_paths_DBN_files:
    contig_name = os.path.basename(DBN_file_path)[:-4]
    if contig_name == '.DS_S' or ContigIsSmall(DBN_file_path,min_length):
        print(contig_name,'skipped')
        continue 
    i+=1
    print(i,'working on ',contig_name)
    free_energy=getFreeEnergy(DBN_file_path) #changes DBN file
    contig=Contig(DBN_file_path,free_energy)
    pickle_path=os.path.join(data_dir,contig_name)
    with open(pickle_path, 'wb') as handle:
       pickle.dump(contig, handle, protocol=pickle.HIGHEST_PROTOCOL)



  return

# %%
class Contig:
  def __init__(self,DBN_file_path,free_energy):
    self.bg, =fgb.BulgeGraph.from_fasta(DBN_file_path)
    self.name = os.path.basename(DBN_file_path)[:-4]
    self.length= self.bg.seq_length
    self.free_energy = float(free_energy)
    self.unpaired_ratio=100*(countUnpaired(DBN_file_path)/(self.length))
    self.stems=Contig.countStems(self.bg)
    self.hairpins=Contig.countHairpins(self.bg)
    self.interior_loops= Contig.countInteriorLoops(self.bg)
    self.multiloops= Contig.countMultiloops(self.bg)


  def countStems(bg):
    cnt=0
    for h in bg.stem_iterator():
      cnt+=1
    return cnt


  def countHairpins(bg):
    cnt=0
    for h in bg.hloop_iterator():
      cnt+=1
    return cnt

  def countInteriorLoops(bg):
    cnt=0
    for i in bg.iloop_iterator():
      cnt+=1
    return cnt

  def countMultiloops(bg):
    junctions=bg.junctions
    reg_multiloops=[]
    cnt=0
    for el in junctions:
      if bg.describe_multiloop(el)=={'regular_multiloop'}:
        cnt +=1
    return cnt 


  def describe_contig(self):
    print('name = ',self.name)
    print('length = ',self.length)
    print('free_energy = ',self.free_energy )
    print('unpaired = ',self.unpaired_ratio)
    print('stems = ',self.stems)
    print('hairpins = ',self.hairpins)
    print('interior_loops = ',self.interior_loops)
    print('multiloops = ',self.multiloops)

# %%
def ContigIsSmall(DBN_file_path,min_length):
    with open(DBN_file_path, 'r') as dbn:
        lines = dbn.readlines()
        length= len(lines[1].strip())
    return (length<min_length)


def copyFolder(original_folder_path,destination,suffix):
  new_folder_name= os.path.basename(original_folder_path)+suffix
  new_folder_path=os.path.join(destination,new_folder_name)
  shutil.copytree(original_folder_path, new_folder_path)
  return new_folder_path

def absoluteFilePaths(directory):
  for dirpath,_,filenames in os.walk(directory):
      for f in filenames:
          yield os.path.abspath(os.path.join(dirpath, f))

#returns free energy and !!!updates!!! DBN file to regular DBN file by removing free energy - value from line 2
def getFreeEnergy(DBN_file_path):
  with open(DBN_file_path,'r') as file:
    content = file.readlines()
  DBNstr = ""
  FreeEnergy = ""
  i=-1
  for x in content[2]:
    i +=1
    if x != " ":
      DBNstr+=x
    else:
      break
  for j in range(i+2,len(content[2])-2):
    FreeEnergy += content[2][j]
  content[2]=DBNstr
  with open(DBN_file_path,'w') as file:
    file.writelines(content)
  return FreeEnergy 

def countUnpaired(DBN_file_path):
  with open(DBN_file_path,'r') as file:
    content = file.readlines()
  cnt=0
  for ch in content[2]:
    if (ch =='.'):
      cnt+=1
  return cnt

# %%
main('/Users/Study/Desktop/BIO project/Data/DBN files/levi','/Users/Study/Desktop/BIO project/Data/Pickled/leviviridae',min_length=3000)
# Out:
# ND_000281 skipped
# ND_002482 skipped
# ND_002455 skipped
# 1 working on  ND_000242
# ND_000256 skipped
# ND_002441 skipped
# ND_003039 skipped
# ND_002469 skipped
# ND_000083 skipped
# ND_000726 skipped
# ND_000732 skipped
# 2 working on  ND_000068
# 3 working on  ND_002938
# ND_000691 skipped
# ND_000685 skipped
# 4 working on  ND_000652
# 5 working on  ND_000646
# 6 working on  ND_003429
# ND_003373 skipped
# 7 working on  ND_003415
# ND_000450 skipped
# ND_000444 skipped
# 8 working on  ND_003171
# 9 working on  ND_003170
# ND_000445 skipped
# ND_000451 skipped
# 10 working on  ND_003414
# 11 working on  ND_003366
# 12 working on  ND_000647
# 13 working on  ND_003428
# 14 working on  ND_000653
# ND_000684 skipped
# 15 working on  ND_002939
# ND_000690 skipped
# 16 working on  ND_000069
# ND_000733 skipped
# ND_000727 skipped
# ND_000082 skipped
# ND_002468 skipped
# ND_002440 skipped
# ND_000257 skipped
# ND_003038 skipped
# 17 working on  ND_000243
# ND_002454 skipped
# ND_000280 skipped
# ND_002481 skipped
# ND_000282 skipped
# ND_000255 skipped
# ND_002456 skipped
# 18 working on  ND_000241
# ND_000269 skipped
# ND_000080 skipped
# ND_000731 skipped
# 19 working on  ND_003238
# ND_000725 skipped
# ND_000719 skipped
# ND_000686 skipped
# ND_000692 skipped
# 20 working on  ND_000645
# 21 working on  ND_000651
# 22 working on  ND_003416
# ND_000679 skipped
# ND_000447 skipped
# 23 working on  ND_003628
# ND_000453 skipped
# 24 working on  ND_003172
# 25 working on  ND_003173
# ND_000452 skipped
# ND_000446 skipped
# 26 working on  ND_003629
# 27 working on  ND_003417
# ND_000678 skipped
# 28 working on  ND_000650
# 29 working on  ND_000644
# ND_000693 skipped
# ND_000687 skipped
# ND_000718 skipped
# ND_000724 skipped
# ND_000730 skipped
# ND_000081 skipped
# ND_000268 skipped
# 30 working on  ND_000240
# ND_002457 skipped
# ND_002443 skipped
# 31 working on  ND_000254
# ND_000283 skipped
# ND_002480 skipped
# ND_002484 skipped
# ND_000287 skipped
# ND_000278 skipped
# 32 working on  ND_000250
# ND_002453 skipped
# 33 working on  ND_000244
# ND_000708 skipped
# ND_000734 skipped
# 34 working on  ND_003229
# ND_000720 skipped
# ND_000683 skipped
# ND_000697 skipped
# 35 working on  ND_003413
# 36 working on  ND_003407
# 37 working on  ND_000668
# 38 working on  ND_000640
# ND_003349 skipped
# 39 working on  ND_000654
# .DS_S skipped
# 40 working on  ND_003188
# 41 working on  ND_003177
# ND_000442 skipped
# 42 working on  ND_003639
# ND_000457 skipped
# 43 working on  ND_003638
# ND_000443 skipped
# 44 working on  ND_003176
# ND_003189 skipped
# 45 working on  ND_000655
# 46 working on  ND_000641
# 47 working on  ND_000669
# 48 working on  ND_003412
# ND_000696 skipped
# ND_000682 skipped
# ND_000721 skipped
# ND_000735 skipped
# ND_000709 skipped
# ND_000084 skipped
# 49 working on  ND_000245
# ND_002452 skipped
# ND_002446 skipped
# 50 working on  ND_000251
# ND_000279 skipped
# ND_000286 skipped
# ND_002485 skipped
# ND_000284 skipped
# ND_002450 skipped
# 51 working on  ND_000247
# 52 working on  ND_003028
# 53 working on  ND_000253
# ND_000079 skipped
# 54 working on  ND_004237
# ND_000737 skipped
# ND_000694 skipped
# ND_000680 skipped
# ND_003404 skipped
# 55 working on  ND_003410
# 56 working on  ND_000657
# 57 working on  ND_003438
# 58 working on  ND_000643
# ND_000469 skipped
# 59 working on  ND_003174
# ND_000455 skipped
# ND_000441 skipped
# ND_000440 skipped
# ND_000454 skipped
# 60 working on  ND_003175
# ND_000468 skipped
# 61 working on  ND_000642
# 62 working on  ND_000656
# ND_003439 skipped
# 63 working on  ND_003411
# 64 working on  ND_003363
# ND_000681 skipped
# ND_000695 skipped
# ND_000736 skipped
# ND_000722 skipped
# ND_000078 skipped
# ND_002445 skipped
# 65 working on  ND_000252
# 66 working on  ND_000246
# ND_002451 skipped
# 67 working on  ND_003029
# ND_002479 skipped
# ND_003940 skipped
# ND_002486 skipped
# ND_000285 skipped
# 68 working on  ND_004084
# ND_003933 skipped
# ND_003099 skipped
# 69 working on  ND_000590
# 70 working on  ND_004090
# ND_003927 skipped
# ND_002436 skipped
# 71 working on  ND_002422
# ND_000786 skipped
# ND_000792 skipped
# ND_000745 skipped
# 72 working on  ND_004245
# ND_000023 skipped
# 73 working on  ND_004251
# ND_000751 skipped
# ND_000779 skipped
# ND_003264 skipped
# ND_000180 skipped
# ND_000816 skipped
# ND_000802 skipped
# 74 working on  ND_000631
# 75 working on  ND_000157
# 76 working on  ND_000625
# ND_003304 skipped
# ND_003462 skipped
# 77 working on  ND_000619
# 78 working on  ND_000396
# 79 working on  ND_003884
# ND_000433 skipped
# ND_000427 skipped
# 80 working on  ND_003648
# 81 working on  ND_003890
# 82 working on  ND_003660
# ND_003674 skipped
# ND_003675 skipped
# 83 working on  ND_003661
# ND_000426 skipped
# 84 working on  ND_003891
# 85 working on  ND_003649
# 86 working on  ND_003885
# ND_000432 skipped
# 87 working on  ND_000397
# 88 working on  ND_000618
# ND_003305 skipped
# ND_003463 skipped
# 89 working on  ND_000624
# 90 working on  ND_000630
# 91 working on  ND_000156
# ND_000803 skipped
# ND_000181 skipped
# 92 working on  ND_004250
# ND_000750 skipped
# ND_000744 skipped
# ND_000022 skipped
# 93 working on  ND_004244
# ND_000793 skipped
# ND_000787 skipped
# 94 working on  ND_002423
# ND_002437 skipped
# 95 working on  ND_000591
# ND_003098 skipped
# ND_003926 skipped
# 96 working on  ND_004091
# ND_003932 skipped
# 97 working on  ND_004085
# 98 working on  ND_004093
# ND_003924 skipped
# 99 working on  ND_000593
# 100 working on  ND_004087
# ND_003930 skipped
# ND_003918 skipped
# 101 working on  ND_002421
# ND_002435 skipped
# 102 working on  ND_002409
# 103 working on  ND_004078
# ND_000791 skipped
# ND_000785 skipped
# ND_000752 skipped
# 104 working on  ND_004252
# 105 working on  ND_004246
# ND_000020 skipped
# ND_000746 skipped
# 106 working on  ND_003267
# 107 working on  ND_000008
# ND_000183 skipped
# ND_002958 skipped
# ND_000829 skipped
# ND_000801 skipped
# ND_000815 skipped
# 108 working on  ND_000626
# ND_003449 skipped
# 109 working on  ND_000154
# 110 working on  ND_000632
# ND_003475 skipped
# 111 working on  ND_000168
# ND_003461 skipped
# ND_003688 skipped
# 112 working on  ND_000395
# ND_004124 skipped
# 113 working on  ND_003893
# ND_000424 skipped
# ND_000430 skipped
# 114 working on  ND_003887
# ND_004118 skipped
# ND_003677 skipped
# ND_000418 skipped
# ND_003663 skipped
# ND_003104 skipped
# ND_003662 skipped
# ND_003676 skipped
# ND_004119 skipped
# ND_000419 skipped
# ND_000431 skipped
# 115 working on  ND_003886
# 116 working on  ND_003892
# ND_004125 skipped
# ND_000425 skipped
# 117 working on  ND_000394
# ND_003689 skipped
# ND_003460 skipped
# 118 working on  ND_000169
# 119 working on  ND_003306
# ND_003474 skipped
# 120 working on  ND_000155
# 121 working on  ND_000633
# 122 working on  ND_000627
# ND_003448 skipped
# ND_000814 skipped
# ND_000800 skipped
# ND_002959 skipped
# ND_000828 skipped
# ND_000182 skipped
# 123 working on  ND_000009
# ND_000021 skipped
# 124 working on  ND_004247
# ND_000747 skipped
# ND_000753 skipped
# 125 working on  ND_004253
# ND_003299 skipped
# ND_000790 skipped
# 126 working on  ND_004079
# 127 working on  ND_002408
# 128 working on  ND_002434
# 129 working on  ND_002420
# ND_003919 skipped
# ND_003931 skipped
# 130 working on  ND_004086
# ND_003925 skipped
# 131 working on  ND_004092
# 132 working on  ND_000592
# ND_003909 skipped
# 133 working on  ND_000596
# 134 working on  ND_004096
# ND_003921 skipped
# 135 working on  ND_004082
# 136 working on  ND_002418
# 137 working on  ND_004069
# 138 working on  ND_002424
# 139 working on  ND_002430
# ND_003048 skipped
# ND_000794 skipped
# ND_000780 skipped
# 140 working on  ND_003262
# ND_000019 skipped
# ND_000757 skipped
# 141 working on  ND_004243
# ND_000025 skipped
# ND_000810 skipped
# 142 working on  ND_002949
# ND_000838 skipped
# ND_003470 skipped
# ND_000179 skipped
# 143 working on  ND_003316
# ND_003464 skipped
# 144 working on  ND_000623
# 145 working on  ND_000637
# ND_003458 skipped
# 146 working on  ND_000390
# ND_003672 skipped
# ND_003666 skipped
# ND_004109 skipped
# 147 working on  ND_000409
# ND_003100 skipped
# ND_000421 skipped
# ND_003128 skipped
# ND_004121 skipped
# 148 working on  ND_003896
# ND_000435 skipped
# ND_000434 skipped
# ND_003129 skipped
# ND_000420 skipped
# 149 working on  ND_003897
# ND_004120 skipped
# ND_004108 skipped
# ND_003667 skipped
# ND_003101 skipped
# 150 working on  ND_000408
# ND_003673 skipped
# 151 working on  ND_000391
# 152 working on  ND_000636
# ND_003459 skipped
# 153 working on  ND_000622
# 154 working on  ND_003303
# ND_003465 skipped
# ND_000178 skipped
# ND_003471 skipped
# 155 working on  ND_002948
# ND_000839 skipped
# ND_000811 skipped
# ND_002960 skipped
# ND_000742 skipped
# ND_000024 skipped
# 156 working on  ND_004242
# ND_000756 skipped
# ND_000018 skipped
# ND_000781 skipped
# 157 working on  ND_003288
# ND_000795 skipped
# 158 working on  ND_002431
# 159 working on  ND_002425
# 160 working on  ND_004068
# 161 working on  ND_002419
# ND_003934 skipped
# 162 working on  ND_004083
# 163 working on  ND_000597
# ND_003920 skipped
# ND_004097 skipped
# ND_003908 skipped
# 164 working on  ND_003088
# 165 working on  ND_004081
# ND_003936 skipped
# 166 working on  ND_004095
# ND_003922 skipped
# 167 working on  ND_000595
# 168 working on  ND_003077
# 169 working on  ND_002433
# 170 working on  ND_002427
# ND_000783 skipped
# ND_000797 skipped
# ND_003275 skipped
# 171 working on  ND_004240
# ND_000026 skipped
# ND_000740 skipped
# 172 working on  ND_003249
# ND_000754 skipped
# ND_000813 skipped
# ND_000807 skipped
# ND_003467 skipped
# 173 working on  ND_003301
# 174 working on  ND_000608
# 175 working on  ND_000634
# 176 working on  ND_000620
# 177 working on  ND_000393
# 178 working on  ND_000387
# ND_003103 skipped
# ND_003665 skipped
# ND_003671 skipped
# 179 working on  ND_003117
# ND_000436 skipped
# 180 working on  ND_003659
# 181 working on  ND_003895
# ND_000422 skipped
# 182 working on  ND_003894
# ND_000423 skipped
# ND_000437 skipped
# 183 working on  ND_003658
# ND_003670 skipped
# ND_003102 skipped
# 184 working on  ND_000392
# 185 working on  ND_000621
# 186 working on  ND_000153
# 187 working on  ND_000635
# ND_003314 skipped
# ND_003472 skipped
# ND_003466 skipped
# 188 working on  ND_000609
# ND_000806 skipped
# ND_000812 skipped
# ND_000755 skipped
# 189 working on  ND_004241
# ND_000741 skipped
# ND_003260 skipped
# ND_000769 skipped
# 190 working on  ND_003274
# ND_000796 skipped
# ND_000782 skipped
# 191 working on  ND_002426
# 192 working on  ND_002432
# 193 working on  ND_003076
# ND_003923 skipped
# 194 working on  ND_004094
# 195 working on  ND_000594
# ND_003089 skipped
# ND_003937 skipped
# 196 working on  ND_004080
# ND_003912 skipped
# 197 working on  ND_003906
# ND_004099 skipped
# 198 working on  ND_000599
# ND_003090 skipped
# 199 working on  ND_003084
# 200 working on  ND_002417
# 201 working on  ND_002403
# 202 working on  ND_004072
# ND_003047 skipped
# ND_003286 skipped
# ND_000764 skipped
# 203 working on  ND_000002
# ND_000016 skipped
# ND_003245 skipped
# ND_000837 skipped
# 204 working on  ND_002946
# 205 working on  ND_002952
# ND_000823 skipped
# ND_003319 skipped
# 206 working on  ND_000610
# ND_000176 skipped
# 207 working on  ND_000162
# 208 working on  ND_000604
# ND_003443 skipped
# ND_003457 skipped
# ND_003331 skipped
# 209 working on  ND_000638
# ND_003682 skipped
# ND_004112 skipped
# 210 working on  ND_000412
# 211 working on  ND_000406
# ND_004106 skipped
# ND_003669 skipped
# 212 working on  ND_003641
# 213 working on  ND_003899
# ND_003127 skipped
# ND_003133 skipped
# 214 working on  ND_003655
# ND_003132 skipped
# 215 working on  ND_003654
# 216 working on  ND_003898
# 217 working on  ND_003640
# ND_003126 skipped
# 218 working on  ND_000407
# ND_003668 skipped
# ND_004107 skipped
# ND_004113 skipped
# 219 working on  ND_000413
# ND_003683 skipped
# ND_003456 skipped
# 220 working on  ND_000639
# ND_003324 skipped
# ND_003442 skipped
# 221 working on  ND_000163
# 222 working on  ND_000605
# 223 working on  ND_000611
# ND_003318 skipped
# ND_000177 skipped
# ND_002953 skipped
# ND_000822 skipped
# ND_000836 skipped
# 224 working on  ND_002947
# 225 working on  ND_003244
# ND_003250 skipped
# ND_000759 skipped
# ND_000017 skipped
# ND_000771 skipped
# ND_000765 skipped
# 226 working on  ND_000003
# ND_003052 skipped
# 227 working on  ND_004073
# 228 working on  ND_002402
# 229 working on  ND_002416
# 230 working on  ND_003085
# ND_004098 skipped
# ND_003091 skipped
# 231 working on  ND_003907
# ND_003913 skipped
# 232 working on  ND_003905
# ND_003911 skipped
# ND_003939 skipped
# 233 working on  ND_003087
# ND_003093 skipped
# 234 working on  ND_002400
# 235 working on  ND_004071
# 236 working on  ND_003078
# 237 working on  ND_002414
# ND_003044 skipped
# ND_003050 skipped
# 238 working on  ND_002428
# ND_000798 skipped
# ND_000773 skipped
# ND_000015 skipped
# 239 working on  ND_000001
# ND_000767 skipped
# 240 working on  ND_003246
# ND_000808 skipped
# ND_000820 skipped
# 241 working on  ND_002951
# 242 working on  ND_002945
# 243 working on  ND_000607
# ND_003468 skipped
# 244 working on  ND_000161
# ND_000175 skipped
# 245 working on  ND_000613
# ND_003454 skipped
# ND_003326 skipped
# ND_003681 skipped
# 246 working on  ND_000388
# ND_004105 skipped
# 247 working on  ND_000405
# 248 working on  ND_000411
# 249 working on  ND_003118
# ND_004111 skipped
# 250 working on  ND_003656
# ND_000439 skipped
# ND_003130 skipped
# ND_003124 skipped
# 251 working on  ND_003642
# ND_003125 skipped
# 252 working on  ND_003643
# 253 working on  ND_003657
# ND_003131 skipped
# ND_000438 skipped
# 254 working on  ND_003119
# 255 working on  ND_000410
# ND_004110 skipped
# ND_004104 skipped
# 256 working on  ND_000404
# 257 working on  ND_000389
# ND_003441 skipped
# ND_003333 skipped
# ND_003455 skipped
# ND_000174 skipped
# 258 working on  ND_000612
# 259 working on  ND_000606
# 260 working on  ND_000160
# ND_003469 skipped
# 261 working on  ND_002944
# ND_000835 skipped
# ND_000821 skipped
# 262 working on  ND_002950
# ND_000809 skipped
# ND_003247 skipped
# ND_000766 skipped
# ND_000772 skipped
# ND_000014 skipped
# ND_000799 skipped
# ND_003051 skipped
# 263 working on  ND_002429
# ND_003045 skipped
# 264 working on  ND_002415
# 265 working on  ND_004070
# 266 working on  ND_002401
# 267 working on  ND_003079
# ND_003092 skipped
# ND_003938 skipped
# 268 working on  ND_003086
# ND_003910 skipped
# 269 working on  ND_003904
# 270 working on  ND_003082
# ND_003928 skipped
# ND_003096 skipped
# 271 working on  ND_003900
# ND_003914 skipped
# ND_003041 skipped
# ND_002439 skipped
# 272 working on  ND_002405
# 273 working on  ND_004074
# 274 working on  ND_002411
# ND_000789 skipped
# 275 working on  ND_000010
# ND_000776 skipped
# ND_000762 skipped
# 276 working on  ND_000004
# ND_002954 skipped
# ND_000825 skipped
# 277 working on  ND_002940
# ND_000819 skipped
# 278 working on  ND_000158
# ND_003451 skipped
# ND_003323 skipped
# ND_003445 skipped
# 279 working on  ND_000164
# 280 working on  ND_000602
# 281 working on  ND_000616
# 282 working on  ND_000170
# 283 working on  ND_000399
# ND_003690 skipped
# ND_003135 skipped
# 284 working on  ND_003653
# 285 working on  ND_003647
# 286 working on  ND_003121
# ND_000428 skipped
# 287 working on  ND_000400
# ND_004100 skipped
# ND_004114 skipped
# 288 working on  ND_000414
# ND_004115 skipped
# 289 working on  ND_000415
# 290 working on  ND_000401
# ND_004101 skipped
# 291 working on  ND_003646
# ND_000429 skipped
# 292 working on  ND_003120
# ND_003134 skipped
# 293 working on  ND_003652
# ND_003685 skipped
# ND_003691 skipped
# 294 working on  ND_000398
# 295 working on  ND_000617
# 296 working on  ND_000171
# 297 working on  ND_000165
# 298 working on  ND_000603
# ND_003322 skipped
# ND_003444 skipped
# ND_003450 skipped
# 299 working on  ND_000159
# ND_000818 skipped
# ND_000830 skipped
# 300 working on  ND_002941
# ND_002955 skipped
# ND_000763 skipped
# 301 working on  ND_000005
# ND_000011 skipped
# 302 working on  ND_003256
# ND_000788 skipped
# 303 working on  ND_002410
# 304 working on  ND_004075
# 305 working on  ND_002404
# ND_003040 skipped
# ND_002438 skipped
# ND_003915 skipped
# 306 working on  ND_003901
# ND_003929 skipped
# ND_003097 skipped
# 307 working on  ND_003083
# ND_003095 skipped
# 308 working on  ND_004088
# 309 working on  ND_003081
# ND_003917 skipped
# 310 working on  ND_003903
# 311 working on  ND_000239
# ND_003042 skipped
# 312 working on  ND_002412
# 313 working on  ND_002406
# 314 working on  ND_004077
# 315 working on  ND_004249
# 316 working on  ND_000007
# ND_003268 skipped
# ND_000761 skipped
# ND_000775 skipped
# ND_000013 skipped
# 317 working on  ND_002943
# ND_000832 skipped
# ND_000826 skipped
# ND_002957 skipped
# ND_003446 skipped
# 318 working on  ND_000629
# 319 working on  ND_003334
# ND_003452 skipped
# 320 working on  ND_000173
# 321 working on  ND_000615
# 322 working on  ND_000601
# 323 working on  ND_000167
# 324 working on  ND_003122
# 325 working on  ND_003644
# 326 working on  ND_003650
# 327 working on  ND_003888
# ND_003136 skipped
# ND_000417 skipped
# ND_003678 skipped
# ND_004117 skipped
# ND_004103 skipped
# 328 working on  ND_000403
# ND_004102 skipped
# 329 working on  ND_000402
# 330 working on  ND_000416
# ND_004116 skipped
# ND_003679 skipped
# 331 working on  ND_003889
# 332 working on  ND_003651
# ND_003123 skipped
# 333 working on  ND_003645
# ND_003692 skipped
# ND_003686 skipped
# ND_003309 skipped
# 334 working on  ND_000600
# 335 working on  ND_000166
# 336 working on  ND_000172
# 337 working on  ND_000614
# ND_003453 skipped
# ND_003447 skipped
# ND_003321 skipped
# 338 working on  ND_000628
# ND_000827 skipped
# ND_002956 skipped
# 339 working on  ND_002942
# ND_000833 skipped
# ND_000774 skipped
# ND_000012 skipped
# 340 working on  ND_000006
# ND_000760 skipped
# ND_000748 skipped
# 341 working on  ND_004248
# 342 working on  ND_003255
# 343 working on  ND_003282
# ND_003296 skipped
# 344 working on  ND_004076
# 345 working on  ND_002407
# 346 working on  ND_002413
# ND_003043 skipped
# 347 working on  ND_000238
# 348 working on  ND_003902
# ND_003916 skipped
# 349 working on  ND_004089
# 350 working on  ND_000589
# 351 working on  ND_003080
# ND_003094 skipped
# ND_000288 skipped
# ND_000263 skipped
# ND_002474 skipped
# ND_002460 skipped
# ND_000277 skipped
# 352 working on  ND_003030
# ND_002448 skipped
# 353 working on  ND_003024
# ND_000707 skipped
# ND_000713 skipped
# ND_000075 skipped
# ND_000698 skipped
# 354 working on  ND_002931
# ND_000673 skipped
# 355 working on  ND_000667
# 356 working on  ND_003408
# 357 working on  ND_003420
# 358 working on  ND_003434
# 359 working on  ND_003187
# ND_003193 skipped
# ND_002266 skipped
# 360 working on  ND_003178
# ND_000471 skipped
# ND_000465 skipped
# ND_002272 skipped
# 361 working on  ND_003636
# ND_000459 skipped
# 362 working on  ND_003637
# ND_000458 skipped
# ND_002273 skipped
# ND_000464 skipped
# ND_000470 skipped
# 363 working on  ND_003179
# ND_002267 skipped
# ND_003192 skipped
# 364 working on  ND_003186
# 365 working on  ND_003435
# 366 working on  ND_003421
# 367 working on  ND_003347
# 368 working on  ND_000666
# 369 working on  ND_003409
# 370 working on  ND_000672
# ND_000699 skipped
# 371 working on  ND_003390
# ND_003233 skipped
# ND_000712 skipped
# ND_000074 skipped
# ND_000706 skipped
# 372 working on  ND_003025
# 373 working on  ND_003031
# ND_002449 skipped
# ND_000276 skipped
# ND_002461 skipped
# ND_002475 skipped
# ND_000262 skipped
# ND_002463 skipped
# ND_000274 skipped
# ND_000260 skipped
# ND_002477 skipped
# 374 working on  ND_003027
# 375 working on  ND_000248
# 376 working on  ND_003033
# ND_000076 skipped
# ND_000710 skipped
# ND_000704 skipped
# 377 working on  ND_003225
# ND_000738 skipped
# 378 working on  ND_004238
# 379 working on  ND_003392
# 380 working on  ND_000664
# 381 working on  ND_000670
# 382 working on  ND_003379
# 383 working on  ND_003437
# 384 working on  ND_000658
# ND_003351 skipped
# 385 working on  ND_003423
# ND_003190 skipped
# 386 working on  ND_003184
# ND_000466 skipped
# ND_002265 skipped
# ND_000472 skipped
# 387 working on  ND_003635
# 388 working on  ND_003634
# ND_000473 skipped
# ND_002264 skipped
# ND_002270 skipped
# ND_000467 skipped
# 389 working on  ND_003185
# ND_003191 skipped
# ND_003344 skipped
# 390 working on  ND_003422
# 391 working on  ND_003436
# ND_003350 skipped
# 392 working on  ND_000659
# 393 working on  ND_000671
# 394 working on  ND_000665
# 395 working on  ND_002933
# 396 working on  ND_003393
# ND_000739 skipped
# 397 working on  ND_004239
# ND_000705 skipped
# ND_000077 skipped
# 398 working on  ND_003218
# 399 working on  ND_003032
# 400 working on  ND_003026
# 401 working on  ND_000249
# ND_002476 skipped
# ND_000261 skipped
# ND_000275 skipped
# ND_002462 skipped
# ND_002489 skipped
# 402 working on  ND_003036
# ND_000259 skipped
# ND_000271 skipped
# ND_000265 skipped
# ND_002472 skipped
# ND_000729 skipped
# ND_003234 skipped
# ND_000715 skipped
# ND_000073 skipped
# 403 working on  ND_000067
# ND_000701 skipped
# 404 working on  ND_003397
# 405 working on  ND_002937
# ND_003383 skipped
# 406 working on  ND_003432
# 407 working on  ND_003426
# 408 working on  ND_000649
# 409 working on  ND_000661
# ND_000675 skipped
# ND_003195 skipped
# 410 working on  ND_003181
# 411 working on  ND_003630
# ND_000463 skipped
# 412 working on  ND_002260
# ND_000476 skipped
# 413 working on  ND_002261
# ND_000462 skipped
# 414 working on  ND_003625
# 415 working on  ND_003631
# 416 working on  ND_003180
# ND_003194 skipped
# ND_000674 skipped
# 417 working on  ND_000660
# 418 working on  ND_003427
# 419 working on  ND_000648
# 420 working on  ND_003433
# 421 working on  ND_003382
# 422 working on  ND_002936
# 423 working on  ND_000066
# ND_000700 skipped
# ND_000714 skipped
# ND_000072 skipped
# ND_003221 skipped
# ND_000728 skipped
# ND_000264 skipped
# ND_000270 skipped
# ND_003037 skipped
# ND_000258 skipped
# 424 working on  ND_003023
# 425 working on  ND_003035
# ND_002459 skipped
# ND_000266 skipped
# ND_002471 skipped
# ND_002465 skipped
# ND_000272 skipped
# 426 working on  ND_003237
# ND_000702 skipped
# 427 working on  ND_000070
# ND_000716 skipped
# ND_000689 skipped
# ND_003380 skipped
# 428 working on  ND_002934
# 429 working on  ND_003343
# 430 working on  ND_003425
# 431 working on  ND_003431
# ND_000676 skipped
# 432 working on  ND_003419
# 433 working on  ND_000662
# 434 working on  ND_003182
# ND_003196 skipped
# 435 working on  ND_003627
# 436 working on  ND_003633
# 437 working on  ND_002263
# ND_000474 skipped
# ND_000460 skipped
# 438 working on  ND_003169
# ND_000461 skipped
# ND_000475 skipped
# 439 working on  ND_002262
# 440 working on  ND_003632
# 441 working on  ND_003626
# ND_000449 skipped
# 442 working on  ND_003183
# 443 working on  ND_000663
# ND_000677 skipped
# 444 working on  ND_003418
# 445 working on  ND_003430
# 446 working on  ND_003424
# 447 working on  ND_002935
# 448 working on  ND_003395
# ND_000688 skipped
# 449 working on  ND_000071
# ND_000717 skipped
# ND_000703 skipped
# 450 working on  ND_003236
# ND_000273 skipped
# ND_002464 skipped
# ND_002470 skipped
# ND_000267 skipped
# ND_002458 skipped
# 451 working on  ND_003034
